# %% [markdown]
# # 🚗 TrafficVision AI - Cloud GPU Runner
# Run TrafficVision AI online with **Free NVIDIA GPU acceleration** directly from GitHub.
#
# Click **Runtime** -> **Run all** (or press `Ctrl+F9`) to start the application.

# %%
# 1. Clone GitHub Repository and Install Dependencies
# !git clone https://github.com/Arka0507/trafficvision-ai.git
# %cd trafficvision-ai
# !pip install -q -r requirements.txt imageio-ffmpeg

# 2. Start FastAPI Server in Background
import subprocess
import time
server_process = subprocess.Popen(["python", "-m", "uvicorn", "backend.main:app", "--host", "0.0.0.0", "--port", "8000"])
time.sleep(3)

# 3. Expose Free Public Web Link via localtunnel
# !npx localtunnel --port 8000
